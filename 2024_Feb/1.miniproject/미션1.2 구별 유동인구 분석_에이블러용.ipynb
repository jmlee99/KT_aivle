# %% [markdown]
# # 안녕하세요^^
# ## AIVLE 1차 미니프로젝트 '서울시 생활정보 기반 대중교통 수요 분석 ' 과정에 오신 여러분을 환영합니다.
# * 본 과정에서는 실제 사례와 데이터를 기반으로 문제를 해결하는 전체 과정을 자기 주도형 실습으로 진행해볼 예정입니다.
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 분석부터 먼저 시작해보겠습니다.
# ## "구 별 유동인구 데이터" 를 확인해 보도록 하겠습니다

# %%
# 필요 라이브러리부터 설치합니다.
# %pip install pandas seaborn

# %% [markdown]
# ## 기본전제
# * 처음에 제공되는 기본/추가 데이터는 '에이블러용' 폴더에 있습니다.
#
# [기본 데이터]
# * seoul_moving_month_202401.csv
#
# [데이터 소개]
# * 서울 시 구별 이동 2024년 1월 데이터
# * https://data.seoul.go.kr/dataVisual/seoul/seoulLivingMigration.do
#
# [변수 소개]
# * 도착시간 : 0 -> "0:00~0:59"를 의미
# * 출발 자치구 : 자치구 코드
# * 성별 : F(여성), M(남성)
# * 나이 : 10 ~ 79세 (5세 단위), 0 ~ 10세, 80세 이상으로 구분
# * 유형 : H(야간상주지), W(주간상주지), E(기타)
# * 평균 이동 시간 : 동일 열 내 이동인구의 월 단위 평균 이동 시간 (10분단위)
# * 이동인구 : 추정 합산값으로 소수점 표출, 개인정보 비식별화를 위해 3명 미만의 경우 * 처리

# %% [markdown]
# ---

# %% [markdown]
# # 1.데이터 불러오기
# ## 모든 미니 프로젝트의 시작은 '데이터 불러오기' 부터라고 할 수 있습니다.
# + KeyPoint : 불러오고자 하는 데이터에 따라 자유롭게 변수로 지정할 수 있다.

# %% [markdown]
# ###  데이터 프레임을 불러오고 변수로 저장(여기서는 CSV 기준으로 진행)
# * csv : pd.read_csv("파일이름. csv")
# * txt : pd.read_csv("파일이름. csv", sep="구분자")
# * xlsx : pd.read_excel('파일이름.xlsx')
# * pickle : pd.read_pickle("파일이름.pkl") <br>
#  [참고] pickle은 파이썬의 모든 객체를 파일로 저장할 수 있는 방법으로 DataFrame,List,Dict 등 모든 객체 저장 가능(특히 sklearn라이브러리를 통해 모델을 학습시키고, 저장할 때 많이 사용)

# %% [markdown]
# #### [실습문제1] 데이터 로딩
# * Pandas 라이브러리를 활용해서 'seoul_moving_month_202401.csv' 데이터를 확인하세요.
#     * 아래에 'Pandas'를 Import하고 'seoul_moving_month_202401.csv'파일을 'seoul_moving'에 불러오고,  Shape을 확인하는 소스코드를 작성하고 실행해보세요.
#     * 데이터 파일 로딩시 참고 사항
#         * 구분자(sep)는 ',' 입니다
#         * UTF-8 인코더를 사용해 주세요

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
import numpy as np
import pandas as pd
import sys
seoul_moving = pd.read_csv('1.2 seoul_moving_month_202401.csv', sep=",", encoding = 'UTF-8')

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# 데이터 프레임의 Shape을 확인합니다.
seoul_moving.shape
# Out:
# (29361031, 10)

# %% [markdown]
# ---

# %% [markdown]
# # 2.기본 정보 확인 및 클렌징
#
# + 데이터 클렌징 : 결측치, 이상치 등을 제거하여 데이터 분석 결과가 왜곡 되는 문제를 방지하기 위한 정제 과정

# %% [markdown]
# #### [실습문제2] 기본 정보 확인하기
# * 'seoul_moving' 데이터의 정보를 확인해보세요.
# * 'describe', 'info', 'head' 등 전부 활용해 보겠습니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# describe()

seoul_moving.describe()
# Out:
#              대상연월          도착시간     출발 시군구 코드     도착 시군구 코드            나이  \
# count  29361031.0  2.936103e+07  2.936103e+07  2.936103e+07  2.936103e+07
# mean     202401.0  1.362194e+01  1.710538e+04  1.718123e+04  4.285979e+01
# std           0.0  5.835017e+00  9.024981e+03  9.037102e+03  1.799456e+01
# min      202401.0  0.000000e+00  1.101000e+04  1.101000e+04  0.000000e+00
# 25%      202401.0  1.000000e+01  1.110000e+04  1.111000e+04  3.000000e+01
# 50%      202401.0  1.400000e+01  1.120000e+04  1.120000e+04  4.000000e+01
# 75%      202401.0  1.800000e+01  3.101400e+04  3.101400e+04  5.500000e+01
# max      202401.0  2.300000e+01  3.900000e+04  3.900000e+04  8.000000e+01
#
#         평균 이동 시간(분)
# count  2.936103e+07
# mean   9.366626e+01
# std    7.803316e+01
# min    1.000000e+00
# 25%    4.900000e+01
# 50%    7.400000e+01
# 75%    1.120000e+02
# max    4.462000e+03

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# info()
seoul_moving.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29361031 entries, 0 to 29361030
# Data columns (total 10 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   대상연월         int64
#  1   요일           object
#  2   도착시간         int64
#  3   출발 시군구 코드    int64
#  4   도착 시군구 코드    int64
#  5   성별           object
#  6   나이           int64
#  7   이동유형         object
#  8   평균 이동 시간(분)  int64
#  9   이동인구(합)      object
# dtypes: int64(6), object(4)
# memory usage: 2.2+ GB

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# head()
seoul_moving.head()
# Out:
#      대상연월 요일  도착시간  출발 시군구 코드  도착 시군구 코드 성별  나이 이동유형  평균 이동 시간(분) 이동인구(합)
# 0  202401  일     0      11010      11010  F   0   EE           20   28.06
# 1  202401  일     0      11010      11010  F  10   EE          167   11.96
# 2  202401  일     0      11010      11010  F  10   EH          203   17.63
# 3  202401  일     0      11010      11010  F  10   HE           23    5.96
# 4  202401  일     0      11010      11010  F  10   WH           27    5.90

# %% [markdown]
# * 1번 열의 의미
#     * " 2024년 1월 일요일에 11010(종로구)에서 11010(종로구)으로 이동하여 0시 ~ 0시 59분 사이에 도착했고, E(기타)에서 E(기타)로 이동한 10 ~ 15세 여성은 총 11.96명이며 이들의 평균 이동시간은 167분이다

# %% [markdown]
# #### [실습문제3] 결측치 처리 ( NaN이 아닌 결측치를 처리 해봅시다)
#
# * '이동인구(합)' column은 이동 인구의 합산인데 object 타입입니다.
#
#     - 왜 일까요?
#
#     - Tip! (이동인구 : 추정 합산값으로 소수점 표출, 개인정보 비식별화를 위해 3명 미만의 경우 * 처리)
#     - 3명 미만의 이동인구는 * 처리 되어 있어서 해당 값을 나름의 기준으로 변경하세요.(중위값)
#     - '이동인구(합)' 컬럼의 데이터 타입을 수치형으로 변경하세요

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# value_counts()
display(seoul_moving.value_counts())
# Out:
# 대상연월    요일  도착시간  출발 시군구 코드  도착 시군구 코드  성별  나이  이동유형  평균 이동 시간(분)  이동인구(합)
# 202401  금   0     11010      11010      F   10  EE    139          12.03      1
#         일   17    11200      11130      F   50  EH    55           18.72      1
#                   11190      11010      M   50  EE    71           32.96      1
#                                             45  WH    60           6.27       1
#                                                 WE    60           6.23       1
#                                                                              ..
#         수   12    11030      31070      M   80  EE    129          6.05       1
#                                             75  HW    185          6.05       1
#                                                 HE    97           5.97       1
#                                                 EH    96           6.04       1
#         화   23    39000      11250      M   50  HE    354          3.27       1
# ...

# %%
# *대체를 위한 중위값 구하기

filter1 = seoul_moving['이동인구(합)'] != '*'
print(seoul_moving['이동인구(합)'][filter1].median().dtype)
seoul_moving['이동인구(합)'][filter1].median()
# Out:
# float64
# 8.1

# %%
# '*' 값의 최빈값과 평균값을 알 수 없는 상황이라 중위값으로 대체 (1.5명)

def Check_col(df):
    if '*' in df:
        return 8.1
    else:
        return df

seoul_moving['이동인구(합)'] = seoul_moving['이동인구(합)'].apply(Check_col)

# %%
# * 없어진지 확인
seoul_moving['이동인구(합)']
# Out:
# 0           28.06
# 1           11.96
# 2           17.63
# 3            5.96
# 4            5.90
#             ...
# 29361026      8.1
# 29361027      8.1
# 29361028     9.47
# 29361029     3.28
# 29361030     6.56
# Name: 이동인구(합), Length: 29361031, dtype: object

# %%
# 이동인구(합) column의 데이터 타입을 바꿔주세요
# astype()

seoul_moving['이동인구(합)'] = seoul_moving['이동인구(합)'].astype(np.float64)
seoul_moving['이동인구(합)'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### [실습문제4] 이동유형, 요일, 성별 변수의 value수를 파악
#
# * 역시나 value_counts()를 활용해 봅시다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# 이동유형, value_counts()
display(seoul_moving['이동유형'].value_counts())
# Out:
# 이동유형
# EH    5947038
# HE    5585412
# EE    5224553
# WH    3078348
# WE    2759477
# HW    2700535
# EW    2330931
# WW    1082641
# HH     652096
# Name: count, dtype: int64

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# 요일, value_counts()
display(seoul_moving['요일'].value_counts())
# Out:
# 요일
# 월    4448237
# 수    4341429
# 화    4300070
# 토    4254525
# 금    4251430
# 목    4005959
# 일    3759381
# Name: count, dtype: int64

# %% [markdown]
# * 24년 1월의 요일 수를 알려드릴게요
#     * 일 : 4, 월 : 5, 화 : 5, 수 : 5, 목 : 4, 금 : 4, 토 : 4

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# 성별, value_counts()
display(seoul_moving['성별'].value_counts())
# Out:
# 성별
# M    16433525
# F    12927506
# Name: count, dtype: int64

# %% [markdown]
# #### [실습문제5] 어느 요일의 심야 이동이 가장 많을까요?

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# 0시 ~ 새벽 5시까지 도착하는 이동 사례, seoul_moving_night 변수 저장

filter2 = seoul_moving['도착시간']<=5
seoul_moving[filter2]['요일'].value_counts()
# Out:
# 요일
# 토    447240
# 월    439563
# 수    414321
# 화    403295
# 금    397406
# 일    387318
# 목    379779
# Name: count, dtype: int64

# %% [markdown]
# #### [실습문제6] 서울 지역의 데이터만 골라 보도록 하겠습니다.
#
# * 우리는 서울시의 데이터만 필요합니다.
# * 시군구 코드:광역시도(2자리)+시군구(3자리) / 서울:11, 부산:26, 대구:27, 인천:28, 광주:29, 대전:30, 울산:31)
#
# * 출발과 도착이 모두 서울인 데이터만 추출해 주세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# 출발 시군구 코드, 도착 시군구 코드 < 20000
filter3 = seoul_moving['출발 시군구 코드'] < 20000
filter4 = seoul_moving['도착 시군구 코드'] < 20000
# filter3먼저 적용 후 filter4적용
df1 = seoul_moving[filter3]
# df1 출발이 서울인곳만 남김
seoul_moving = df1[filter4]
seoul_moving.reset_index(drop = True, inplace = True)
seoul_moving
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15616\3247942409.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   seoul_moving = df1[filter4]
#             대상연월 요일  도착시간  출발 시군구 코드  도착 시군구 코드 성별  나이 이동유형  평균 이동 시간(분)  \
# 0         202401  일     0      11010      11010  F   0   EE           20
# 1         202401  일     0      11010      11010  F  10   EE          167
# 2         202401  일     0      11010      11010  F  10   EH          203
# 3         202401  일     0      11010      11010  F  10   HE           23
# 4         202401  일     0      11010      11010  F  10   WH           27
# ...          ... ..   ...        ...        ... ..  ..  ...          ...
# 10791764  202401  토    23      11250      11250  M  80   EH           18
# 10791765  202401  토    23      11250      11250  M  80   HE           78
# 10791766  202401  토    23      11250      11250  M  80   HW          168
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %% [markdown]
# #### [실습문제7] 서울지역의 구 별로 groupby하여 데이터를 확인하겠습니다 (유동인구 기준)
#
# * 유출이 제일 많은 구는?
#
# * 유입이 제일 많은 구는?
#
# * 유출이 제일 적은 구는?
#
# * 유입이 제일 적은 구는?

# %% [markdown]
# * 참고자료 서울 구별 코드
#     * 11010	종로구
#     * 11020	중구
#     * 11030	용산구
#     * 11040	성동구
#     * 11050	광진구
#     * 11060	동대문구
#     * 11070	중랑구
#     * 11080	성북구
#     * 11090	강북구
#     * 11100	도봉구
#     * 11110	노원구
#     * 11120	은평구
#     * 11130	서대문구
#     * 11140	마포구
#     * 11150	양천구
#     * 11160	강서구
#     * 11170	구로구
#     * 11180	금천구
#     * 11190	영등포구
#     * 11200	동작구
#     * 11210	관악구
#     * 11220	서초구
#     * 11230	강남구
#     * 11240	송파구
#     * 11250	강동구

# %%
# 자치구 맵핑
seoul_moving['출발 시군구 코드'] = seoul_moving['출발 시군구 코드'].astype(str)
seoul_moving['도착 시군구 코드'] = seoul_moving['도착 시군구 코드'].astype(str)
seoul_moving
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15616\977667810.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_moving['출발 시군구 코드'] = seoul_moving['출발 시군구 코드'].astype(str)
# C:\Users\User\AppData\Local\Temp\ipykernel_15616\977667810.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_moving['도착 시군구 코드'] = seoul_moving['도착 시군구 코드'].astype(str)
#             대상연월 요일  도착시간 출발 시군구 코드 도착 시군구 코드 성별  나이 이동유형  평균 이동 시간(분)  \
# ...

# %%
seoul_moving
# Out:
#             대상연월 요일  도착시간 출발 시군구 코드 도착 시군구 코드 성별  나이 이동유형  평균 이동 시간(분)  \
# 0         202401  일     0     11010     11010  F   0   EE           20
# 1         202401  일     0     11010     11010  F  10   EE          167
# 2         202401  일     0     11010     11010  F  10   EH          203
# 3         202401  일     0     11010     11010  F  10   HE           23
# 4         202401  일     0     11010     11010  F  10   WH           27
# ...          ... ..   ...       ...       ... ..  ..  ...          ...
# 10791764  202401  토    23     11250     11250  M  80   EH           18
# 10791765  202401  토    23     11250     11250  M  80   HE           78
# 10791766  202401  토    23     11250     11250  M  80   HW          168
# 10791767  202401  토    23     11250     11250  M  80   WH           16
# 10791768  202401  토    23     11250     11250  M  80   WW           78
#
#           이동인구(합)
# 0           28.06
# 1           11.96
# 2           17.63
# 3            5.96
# ...

# %%
# 혹시 모르니 원본 저장
df1 = seoul_moving
df1
# Out:
#             대상연월 요일  도착시간 출발 시군구 코드 도착 시군구 코드 성별  나이 이동유형  평균 이동 시간(분)  \
# 0         202401  일     0     11010     11010  F   0   EE           20
# 1         202401  일     0     11010     11010  F  10   EE          167
# 2         202401  일     0     11010     11010  F  10   EH          203
# 3         202401  일     0     11010     11010  F  10   HE           23
# 4         202401  일     0     11010     11010  F  10   WH           27
# ...          ... ..   ...       ...       ... ..  ..  ...          ...
# 10791764  202401  토    23     11250     11250  M  80   EH           18
# 10791765  202401  토    23     11250     11250  M  80   HE           78
# 10791766  202401  토    23     11250     11250  M  80   HW          168
# 10791767  202401  토    23     11250     11250  M  80   WH           16
# 10791768  202401  토    23     11250     11250  M  80   WW           78
#
#           이동인구(합)
# 0           28.06
# 1           11.96
# 2           17.63
# 3            5.96
# ...

# %%
df1['출발 시군구 코드'] = df1['출발 시군구 코드'].map({
    '11010' : '종로구',
    '11020' : '중구',
    '11030' : '용산구',
    '11040' : '성동구',
    '11050' : '광진구',
    '11060' : '동대문구',
    '11070' : '중랑구',
    '11080' : '성북구',
    '11090' : '강북구',
    '11100' : '도봉구',
    '11110' : '노원구',
    '11120' : '은평구',
    '11130' : '서대문구',
    '11140' : '마포구',
    '11150' : '양천구',
    '11160' : '강서구',
    '11170' : '구로구',
    '11180' : '금천구',
    '11190' : '영등포구',
    '11200' : '동작구',
    '11210' : '관악구',
    '11220' : '서초구',
    '11230' : '강남구',
    '11240' : '송파구',
    '11250' : '강동구'})

# %%
df1['도착 시군구 코드'] = df1['도착 시군구 코드'].map({
    '11010' : '종로구',
    '11020' : '중구',
    '11030' : '용산구',
    '11040' : '성동구',
    '11050' : '광진구',
    '11060' : '동대문구',
    '11070' : '중랑구',
    '11080' : '성북구',
    '11090' : '강북구',
    '11100' : '도봉구',
    '11110' : '노원구',
    '11120' : '은평구',
    '11130' : '서대문구',
    '11140' : '마포구',
    '11150' : '양천구',
    '11160' : '강서구',
    '11170' : '구로구',
    '11180' : '금천구',
    '11190' : '영등포구',
    '11200' : '동작구',
    '11210' : '관악구',
    '11220' : '서초구',
    '11230' : '강남구',
    '11240' : '송파구',
    '11250' : '강동구'})

# %%
df1
# Out:
#             대상연월 요일  도착시간 출발 시군구 코드 도착 시군구 코드 성별  나이 이동유형  평균 이동 시간(분)  \
# 0         202401  일     0       종로구       종로구  F   0   EE           20
# 1         202401  일     0       종로구       종로구  F  10   EE          167
# 2         202401  일     0       종로구       종로구  F  10   EH          203
# 3         202401  일     0       종로구       종로구  F  10   HE           23
# 4         202401  일     0       종로구       종로구  F  10   WH           27
# ...          ... ..   ...       ...       ... ..  ..  ...          ...
# 10791764  202401  토    23       강동구       강동구  M  80   EH           18
# 10791765  202401  토    23       강동구       강동구  M  80   HE           78
# 10791766  202401  토    23       강동구       강동구  M  80   HW          168
# 10791767  202401  토    23       강동구       강동구  M  80   WH           16
# 10791768  202401  토    23       강동구       강동구  M  80   WW           78
#
#           이동인구(합)
# 0           28.06
# 1           11.96
# 2           17.63
# 3            5.96
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# 유출이 제일 많은 구와 적은 구는?
filter1 = df1.groupby('출발 시군구 코드')['이동유형'].count() == df1.groupby('출발 시군구 코드')['이동유형'].count().max() 
filter2 = df1.groupby('출발 시군구 코드')['이동유형'].count() == df1.groupby('출발 시군구 코드')['이동유형'].count().min() 

g1 = df1.groupby('출발 시군구 코드')[['이동유형']].count()


print('유출 가장 많은 구 :')
display(g1[filter1])
print()
print('=' * 30)
print()
print('유출 가장 적은 구 :')
display(g1[filter2])
# Out:
# 유출 가장 많은 구 :
#              이동유형
# 출발 시군구 코드
# 강남구        586427
# ...
#
# 유출 가장 적은 구 :
#              이동유형
# 출발 시군구 코드
# 금천구        298701

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# 유입이 제일 많은 구와 적은 구는?
filter1 = df1.groupby('도착 시군구 코드')['이동유형'].count() == df1.groupby('도착 시군구 코드')['이동유형'].count().max() 
filter2 = df1.groupby('도착 시군구 코드')['이동유형'].count() == df1.groupby('도착 시군구 코드')['이동유형'].count().min() 

g2 = df1.groupby('도착 시군구 코드')[['이동유형']].count()


print('유입 가장 많은 구 :')
display(g2[filter1])
print()
print('=' * 30)
print()
print('유입 가장 적은 구 :')
display(g2[filter2])
# Out:
# 유입 가장 많은 구 :
#              이동유형
# 도착 시군구 코드
# 강남구        564757
# ...
#
# 유입 가장 적은 구 :
#              이동유형
# 도착 시군구 코드
# 금천구        296192

# %% [markdown]
# #### [실습문제8] 낮시간만 볼게요 심야버스 제외하겠습니다
#
# * 도착시간 0부터 4까지(0:00 ~ 4:59) 제거

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# '도착시간' >=5
filter2 = seoul_moving['도착시간']>=5
morning_df = seoul_moving[filter2]
morning_df
# Out:
#             대상연월 요일  도착시간 출발 시군구 코드 도착 시군구 코드 성별  나이 이동유형  평균 이동 시간(분)  \
# 1135049   202401  일     5       종로구       종로구  F   0   HE           54
# 1135050   202401  일     5       종로구       종로구  F   0   HW           30
# 1135051   202401  일     5       종로구       종로구  F  10   EE           54
# 1135052   202401  일     5       종로구       종로구  F  10   HE           13
# 1135053   202401  일     5       종로구       종로구  F  15   EH           44
# ...          ... ..   ...       ...       ... ..  ..  ...          ...
# 10791764  202401  토    23       강동구       강동구  M  80   EH           18
# 10791765  202401  토    23       강동구       강동구  M  80   HE           78
# 10791766  202401  토    23       강동구       강동구  M  80   HW          168
# 10791767  202401  토    23       강동구       강동구  M  80   WH           16
# 10791768  202401  토    23       강동구       강동구  M  80   WW           78
#
#           이동인구(합)
# 1135049     28.28
# 1135050     28.03
# 1135051      6.00
# 1135052      5.82
# ...

# %% [markdown]
# [실습문제9] '도착 시군구 코드' 를 기준으로 각 구별로 '평균 이동 시간(분)' , '이동인구(합)' 의 평균 과 합을 구해보겠습니다
#
# * groupby 사용, as_index=False로 설정해주세요

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# 평균을 구해서 df_mean 변수로 저장
df_mean = df1.groupby('도착 시군구 코드', as_index=False)[['평균 이동 시간(분)', '이동인구(합)']].mean()
df_mean
# Out:
#    도착 시군구 코드  평균 이동 시간(분)    이동인구(합)
# 0        강남구    66.010258  88.998245
# 1        강동구    72.597698  63.301129
# 2        강북구    66.486808  36.904255
# 3        강서구    70.960191  58.195750
# 4        관악구    64.366885  47.856729
# 5        광진구    61.807174  43.230918
# 6        구로구    65.307127  41.984565
# 7        금천구    67.409332  30.764639
# 8        노원구    67.933710  50.795450
# 9        도봉구    68.365541  36.063607
# 10      동대문구    60.745357  38.403632
# 11       동작구    59.793027  39.378754
# 12       마포구    61.929110  52.089388
# 13      서대문구    61.386553  41.025626
# 14       서초구    64.032968  63.899530
# 15       성동구    58.879851  39.507183
# 16       성북구    60.975391  42.318336
# 17       송파구    71.786619  79.884417
# 18       양천구    62.972306  44.545082
# 19      영등포구    61.308071  54.920038
# 20       용산구    58.494740  34.761795
# 21       은평구    69.197208  48.675685
# 22       종로구    60.151307  42.386094
# 23        중구    58.450528  44.580830
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
# 합을 구해서 df_sum 변수로 저장
# 평균이동시간(분) -> 총 이동 시간, 이동인구(합) -> 총 이동인구로 이름 대체
df_sum = df1.groupby('도착 시군구 코드', as_index=False)[['평균 이동 시간(분)', '이동인구(합)']].sum()
df_sum.columns = ['도착 시군구 코드', '총 이동 시간', '총 이동 인구']
df_sum
# Out:
#    도착 시군구 코드   총 이동 시간      총 이동 인구
# 0        강남구  37279755  50262381.76
# 1        강동구  27092372  23623032.00
# 2        강북구  23924081  13279331.81
# 3        강서구  30486485  25002523.50
# 4        관악구  27501846  20447600.99
# 5        광진구  26804906  18748643.87
# 6        구로구  25722714  16536586.44
# 7        금천구  19966105   9112239.94
# 8        노원구  28628896  21406421.81
# 9        도봉구  22060398  11637112.81
# 10      동대문구  28277328  17877121.21
# 11       동작구  26048952  17155433.15
# 12       마포구  30225617  25423163.24
# 13      서대문구  26741640  17871870.21
# 14       서초구  32412912  32345366.89
# 15       성동구  27279447  18303954.27
# 16       성북구  27954290  19400925.71
# 17       송파구  33877900  37699453.50
# 18       양천구  22624816  16004246.03
# 19      영등포구  30748266  27544431.32
# 20       용산구  26487237  15740627.28
# 21       은평구  25717696  18090707.78
# 22       종로구  29075578  20488335.86
# 23        중구  28733286  21915178.29
# 24       중랑구  25059916  15084101.97

# %%
# 파일을 합쳐볼까요
# pd.merge()

# df_mean
# df_sum
seoul_moving_total = pd.merge(df_mean, df_sum, how = 'inner')
seoul_moving_total
# Out:
#    도착 시군구 코드  평균 이동 시간(분)    이동인구(합)   총 이동 시간      총 이동 인구
# 0        강남구    66.010258  88.998245  37279755  50262381.76
# 1        강동구    72.597698  63.301129  27092372  23623032.00
# 2        강북구    66.486808  36.904255  23924081  13279331.81
# 3        강서구    70.960191  58.195750  30486485  25002523.50
# 4        관악구    64.366885  47.856729  27501846  20447600.99
# 5        광진구    61.807174  43.230918  26804906  18748643.87
# 6        구로구    65.307127  41.984565  25722714  16536586.44
# 7        금천구    67.409332  30.764639  19966105   9112239.94
# 8        노원구    67.933710  50.795450  28628896  21406421.81
# 9        도봉구    68.365541  36.063607  22060398  11637112.81
# 10      동대문구    60.745357  38.403632  28277328  17877121.21
# 11       동작구    59.793027  39.378754  26048952  17155433.15
# 12       마포구    61.929110  52.089388  30225617  25423163.24
# 13      서대문구    61.386553  41.025626  26741640  17871870.21
# 14       서초구    64.032968  63.899530  32412912  32345366.89
# ...

# %%
# 해당 데이터프레임을 csv 파일로 저장하세요
# to_csv()
seoul_moving_total.to_csv("seoul_moving_total.csv")

# %% [markdown]
# ---

# %% [markdown]
# # 3.데이터 분석하기
# + KeyPoint : 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별할 수 있다.
#   * 데이터들의 패턴 탐색
#   * 변수들간의 관계 파악

# %%
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %% [markdown]
# #### [실습문제10] 데이터 분포 알아보기
# * 다양한 변수를 기준으로 그래프를 그려보고 인사이트를 도출해보세요.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.

# %%
# 위 차트를 통해 알게된 사실을 정리해봅시다.
# 1. 
# 2.
# 3.

# %% [markdown]
# ---
