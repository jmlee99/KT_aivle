# %% [markdown]
# # 딥러닝3 : 다중분류

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 함수 만들기

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (2) 데이터로딩

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/iris.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# ### (1) y 값을 0,1,2로 변환하기
# (sparse_categorical_crossentropy 사용을 위해)

# %%
data['Species'] = data['Species'].map({'setosa':0, 'versicolor':1, 'virginica':2})
data.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %% [markdown]
# ### (2) 데이터 준비

# %%
target = 'Species'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# ### (3) 데이터 분할 : train : val

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = .3, random_state = 20)

# %% [markdown]
# ### (4) Scaling

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ## 3.모델링1

# %% [markdown]
# ### (1) 모델 설계

# %%
nfeatures = x_train.shape[1] #num of columns
nfeatures
# Out:
# 4

# %%
# 메모리 정리
clear_session()

# Sequential
model = Sequential( Dense( 3 , input_shape = (nfeatures,), activation = 'softmax') )

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 3)                 15
#
# =================================================================
# Total params: 15 (60.00 Byte)
# Trainable params: 15 (60.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### (2) compile + 학습

# %%
model.compile(optimizer=Adam(learning_rate=0.1), loss= 'sparse_categorical_crossentropy')

history = model.fit(x_train, y_train, epochs = 50, validation_split=0.2).history
# Out:
# Epoch 1/50
# 3/3 [==============================] - 1s 111ms/step - loss: 0.9452 - val_loss: 0.8224
# Epoch 2/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8155 - val_loss: 0.6728
# Epoch 3/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7034 - val_loss: 0.5800
# Epoch 4/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6292 - val_loss: 0.5093
# Epoch 5/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.5707 - val_loss: 0.4590
# Epoch 6/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5219 - val_loss: 0.4270
# Epoch 7/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4852 - val_loss: 0.3990
# Epoch 8/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4557 - val_loss: 0.3724
# Epoch 9/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4284 - val_loss: 0.3506
# Epoch 10/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4106 - val_loss: 0.3348
# Epoch 11/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.3931 - val_loss: 0.3218
# Epoch 12/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3743 - val_loss: 0.3097
# Epoch 13/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3606 - val_loss: 0.3005
# Epoch 14/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3489 - val_loss: 0.2892
# Epoch 15/50
# 3/3 [==============================] - 0s 59ms/step - loss: 0.3408 - val_loss: 0.2805
# Epoch 16/50
# 3/3 [==============================] - 0s 126ms/step - loss: 0.3264 - val_loss: 0.2725
# Epoch 17/50
# 3/3 [==============================] - 0s 82ms/step - loss: 0.3171 - val_loss: 0.2663
# Epoch 18/50
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3091 - val_loss: 0.2595
# Epoch 19/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3008 - val_loss: 0.2524
# Epoch 20/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2936 - val_loss: 0.2464
# Epoch 21/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2867 - val_loss: 0.2410
# Epoch 22/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2811 - val_loss: 0.2355
# Epoch 23/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2763 - val_loss: 0.2308
# Epoch 24/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2691 - val_loss: 0.2269
# Epoch 25/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2650 - val_loss: 0.2221
# Epoch 26/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2586 - val_loss: 0.2181
# Epoch 27/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2553 - val_loss: 0.2139
# Epoch 28/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2501 - val_loss: 0.2097
# Epoch 29/50
# 3/3 [==============================] - 0s 42ms/step - loss: 0.2449 - val_loss: 0.2066
# Epoch 30/50
# 3/3 [==============================] - 0s 102ms/step - loss: 0.2413 - val_loss: 0.2026
# Epoch 31/50
# 3/3 [==============================] - 0s 52ms/step - loss: 0.2404 - val_loss: 0.1999
# Epoch 32/50
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2341 - val_loss: 0.1961
# Epoch 33/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2370 - val_loss: 0.1941
# Epoch 34/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2267 - val_loss: 0.1903
# Epoch 35/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2243 - val_loss: 0.1892
# Epoch 36/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2215 - val_loss: 0.1849
# Epoch 37/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2172 - val_loss: 0.1819
# Epoch 38/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2139 - val_loss: 0.1793
# Epoch 39/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2122 - val_loss: 0.1771
# Epoch 40/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2085 - val_loss: 0.1745
# Epoch 41/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2058 - val_loss: 0.1722
# Epoch 42/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2032 - val_loss: 0.1707
# Epoch 43/50
# 3/3 [==============================] - 0s 72ms/step - loss: 0.2006 - val_loss: 0.1679
# Epoch 44/50
# 3/3 [==============================] - 0s 83ms/step - loss: 0.1986 - val_loss: 0.1655
# Epoch 45/50
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1958 - val_loss: 0.1634
# Epoch 46/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1924 - val_loss: 0.1621
# Epoch 47/50
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1916 - val_loss: 0.1614
# Epoch 48/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1900 - val_loss: 0.1591
# Epoch 49/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1873 - val_loss: 0.1558
# Epoch 50/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1842 - val_loss: 0.1539

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# ### (3) 예측 및 검증
# * 예측 결과는 softmax로 변환된 값 입니다.

# %%
y_val[:5]
# Out:
# 47     0
# 73     1
# 74     1
# 129    2
# 67     1
# Name: Species, dtype: int64

# %%
pred = model.predict(x_val)
pred[:5]
# Out:
# 2/2 [==============================] - 0s 9ms/step
# array([[9.7982794e-01, 2.0134792e-02, 3.7200145e-05],
#        [1.0321735e-02, 8.3587885e-01, 1.5379937e-01],
#        [1.2357173e-02, 7.7917618e-01, 2.0846663e-01],
#        [3.7046030e-04, 3.9276809e-01, 6.0686147e-01],
#        [3.1649716e-02, 9.0574265e-01, 6.2607631e-02]], dtype=float32)

# %% [markdown]
# * 행 별로 제일 큰 값을 찾아서 그에 맞게 숫자(0,1,2)로 변환 합시다.

# %%
# 5개 행만 살펴보면
np.argmax(pred[:5], axis = 1)
# Out:
# array([0, 1, 1, 2, 1])

# %%
# 전체에 적용해서 변환합시다.
pred_1 = pred.argmax(axis=1)
pred_1
# Out:
# array([0, 1, 1, 2, 1, 1, 2, 0, 2, 0, 2, 1, 1, 0, 0, 2, 0, 1, 2, 1, 1, 2,
#        2, 0, 1, 1, 1, 0, 2, 1, 1, 1, 0, 0, 0, 1, 1, 0, 1, 2, 1, 1, 0, 1,
#        1])

# %% [markdown]
# * 실제값 y_val은 0,1,2 로 된 1차원 값입니다.

# %%
y_val
# Out:
# 47     0
# 73     1
# 74     1
# 129    2
# 67     1
# 89     1
# 143    2
# 21     0
# 108    2
# 12     0
# 147    2
# 76     1
# 119    2
# 35     0
# 28     0
# 122    2
# 13     0
# 58     1
# 114    2
# 57     1
# 50     1
# 149    2
# 111    2
# 20     0
# 72     1
# 81     1
# 98     1
# 34     0
# 104    2
# 133    2
# 95     1
# 88     1
# 0      0
# 46     0
# 11     0
# 106    2
# 85     1
# 1      0
# 51     1
# 130    2
# 55     1
# 134    2
# 37     0
# 65     1
# 56     1
# Name: Species, dtype: int64

# %%
print(confusion_matrix(y_val, pred_1))
print(classification_report(y_val, pred_1))
# Out:
# [[13  0  0]
#  [ 0 18  0]
#  [ 0  4 10]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.82      1.00      0.90        18
#            2       1.00      0.71      0.83        14
#
#     accuracy                           0.91        45
#    macro avg       0.94      0.90      0.91        45
# weighted avg       0.93      0.91      0.91        45

# %% [markdown]
# ----

# %% [markdown]
# ## 4.모델링2 : hidden layer

# %% [markdown]
# ### (1) 모델1

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape | Param # | 옵션 |
# | ---- | ---- | ---- | ---- |
# | dense (Dense) | (None, 8) | 40 | node, input_shape, activation = 'relu' |
# | dense_1 (Dense) | (None, 3) | 27 | node, activation = 'softmax'  |

# %%
# 메모리 정리
clear_session()

# Sequential 타입 모델 선언
model = Sequential([Dense(8 , input_shape = (nfeatures,), activation = 'relu'),
                    Dense(3 , activation = 'softmax') ])

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 40
#
#  dense_1 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 67 (268.00 Byte)
# Trainable params: 67 (268.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# * compile + 학습

# %%
model.compile(optimizer=Adam(learning_rate=0.01), loss= 'sparse_categorical_crossentropy')

history = model.fit(x_train, y_train, epochs = 50, validation_split=0.2).history
# Out:
# Epoch 1/50
# 3/3 [==============================] - 1s 98ms/step - loss: 1.1392 - val_loss: 1.1152
# Epoch 2/50
# 3/3 [==============================] - 0s 21ms/step - loss: 1.1117 - val_loss: 1.0938
# Epoch 3/50
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0928 - val_loss: 1.0762
# Epoch 4/50
# 3/3 [==============================] - 0s 20ms/step - loss: 1.0797 - val_loss: 1.0630
# Epoch 5/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0664 - val_loss: 1.0490
# Epoch 6/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0530 - val_loss: 1.0352
# Epoch 7/50
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0400 - val_loss: 1.0179
# Epoch 8/50
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0236 - val_loss: 0.9984
# Epoch 9/50
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0062 - val_loss: 0.9740
# Epoch 10/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9838 - val_loss: 0.9456
# Epoch 11/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9591 - val_loss: 0.9158
# Epoch 12/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.9321 - val_loss: 0.8835
# Epoch 13/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.9041 - val_loss: 0.8493
# Epoch 14/50
# 3/3 [==============================] - 0s 31ms/step - loss: 0.8748 - val_loss: 0.8127
# Epoch 15/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8409 - val_loss: 0.7765
# Epoch 16/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8081 - val_loss: 0.7373
# Epoch 17/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.7731 - val_loss: 0.6975
# Epoch 18/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.7388 - val_loss: 0.6577
# Epoch 19/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7027 - val_loss: 0.6179
# Epoch 20/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6707 - val_loss: 0.5805
# Epoch 21/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6368 - val_loss: 0.5464
# Epoch 22/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6062 - val_loss: 0.5151
# Epoch 23/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.5786 - val_loss: 0.4863
# Epoch 24/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5531 - val_loss: 0.4606
# Epoch 25/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5295 - val_loss: 0.4382
# Epoch 26/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5087 - val_loss: 0.4188
# Epoch 27/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4889 - val_loss: 0.4022
# Epoch 28/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4726 - val_loss: 0.3871
# Epoch 29/50
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4565 - val_loss: 0.3746
# Epoch 30/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4439 - val_loss: 0.3639
# Epoch 31/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4312 - val_loss: 0.3533
# Epoch 32/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4203 - val_loss: 0.3424
# Epoch 33/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4086 - val_loss: 0.3330
# Epoch 34/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3986 - val_loss: 0.3241
# Epoch 35/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3891 - val_loss: 0.3160
# Epoch 36/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3803 - val_loss: 0.3086
# Epoch 37/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3717 - val_loss: 0.3018
# Epoch 38/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3632 - val_loss: 0.2952
# Epoch 39/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3564 - val_loss: 0.2895
# Epoch 40/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3479 - val_loss: 0.2833
# Epoch 41/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3406 - val_loss: 0.2770
# Epoch 42/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3326 - val_loss: 0.2713
# Epoch 43/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3254 - val_loss: 0.2655
# Epoch 44/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3182 - val_loss: 0.2598
# Epoch 45/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3115 - val_loss: 0.2544
# Epoch 46/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3046 - val_loss: 0.2490
# Epoch 47/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.3006 - val_loss: 0.2439
# Epoch 48/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2915 - val_loss: 0.2391
# Epoch 49/50
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2857 - val_loss: 0.2350
# Epoch 50/50
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2800 - val_loss: 0.2300

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# * 예측 및 검증
#     * 예측 결과는 softmax로 변환된 값 입니다.

# %%
pred = model.predict(x_val)
pred_1 = pred.argmax(axis=1)
# Out:
# 2/2 [==============================] - 0s 6ms/step

# %%
print(confusion_matrix(y_val, pred_1))
print(classification_report(y_val, pred_1))
# Out:
# [[13  0  0]
#  [ 0 16  2]
#  [ 0  1 13]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.94      0.89      0.91        18
#            2       0.87      0.93      0.90        14
#
#     accuracy                           0.93        45
#    macro avg       0.94      0.94      0.94        45
# weighted avg       0.93      0.93      0.93        45

# %% [markdown]
# ### (2) 모델2

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape | Param # | 옵션 |
# | ---- | ---- | ---- | ---- |
# | dense (Dense) | (None, 8) | 40 | node, input_shape, activation = 'relu' |
# | dense_1 (Dense) | (None, 8) | 72 | node, activation = 'relu'  |
# | dense_2 (Dense) | (None, 3) | 27 | node, activation = 'softmax'  |

# %%
# 메모리 정리
clear_session()

# Sequential 타입 모델 선언
model = Sequential([Dense(8 , input_shape = (nfeatures,), activation = 'relu'),
                    Dense(8 , activation = 'relu'),
                    Dense(3 , activation = 'softmax') ]) # 각 클래스에 속할 확률

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 40
#
#  dense_1 (Dense)             (None, 8)                 72
#
#  dense_2 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 139 (556.00 Byte)
# Trainable params: 139 (556.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# * compile + 학습

# %%
model.compile(optimizer=Adam(learning_rate=0.01), loss= 'sparse_categorical_crossentropy')

history = model.fit(x_train, y_train, epochs = 50, validation_split=0.2).history
# Out:
# Epoch 1/50
# 3/3 [==============================] - 3s 199ms/step - loss: 1.1055 - val_loss: 1.0919
# Epoch 2/50
# 3/3 [==============================] - 0s 40ms/step - loss: 1.0926 - val_loss: 1.0856
# Epoch 3/50
# 3/3 [==============================] - 0s 40ms/step - loss: 1.0861 - val_loss: 1.0647
# Epoch 4/50
# 3/3 [==============================] - 0s 28ms/step - loss: 1.0527 - val_loss: 1.0084
# Epoch 5/50
# 3/3 [==============================] - 0s 36ms/step - loss: 1.0102 - val_loss: 0.9888
# Epoch 6/50
# 3/3 [==============================] - 0s 37ms/step - loss: 0.9844 - val_loss: 0.9533
# Epoch 7/50
# 3/3 [==============================] - 0s 36ms/step - loss: 0.9515 - val_loss: 0.9055
# Epoch 8/50
# 3/3 [==============================] - 0s 37ms/step - loss: 0.9101 - val_loss: 0.8429
# Epoch 9/50
# 3/3 [==============================] - 0s 41ms/step - loss: 0.8615 - val_loss: 0.7802
# Epoch 10/50
# 3/3 [==============================] - 0s 41ms/step - loss: 0.8076 - val_loss: 0.7189
# Epoch 11/50
# 3/3 [==============================] - 0s 35ms/step - loss: 0.7514 - val_loss: 0.6602
# Epoch 12/50
# 3/3 [==============================] - 0s 36ms/step - loss: 0.6955 - val_loss: 0.6031
# Epoch 13/50
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6413 - val_loss: 0.5486
# Epoch 14/50
# 3/3 [==============================] - 0s 45ms/step - loss: 0.5923 - val_loss: 0.5008
# Epoch 15/50
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5495 - val_loss: 0.4577
# Epoch 16/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.5132 - val_loss: 0.4256
# Epoch 17/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.4853 - val_loss: 0.4006
# Epoch 18/50
# 3/3 [==============================] - 0s 37ms/step - loss: 0.4615 - val_loss: 0.3810
# Epoch 19/50
# 3/3 [==============================] - 0s 35ms/step - loss: 0.4410 - val_loss: 0.3649
# Epoch 20/50
# 3/3 [==============================] - 0s 28ms/step - loss: 0.4191 - val_loss: 0.3550
# Epoch 21/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.4105 - val_loss: 0.3509
# Epoch 22/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.3990 - val_loss: 0.3334
# Epoch 23/50
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3831 - val_loss: 0.3204
# Epoch 24/50
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3680 - val_loss: 0.3106
# Epoch 25/50
# 3/3 [==============================] - 0s 30ms/step - loss: 0.3575 - val_loss: 0.3007
# Epoch 26/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3444 - val_loss: 0.2901
# Epoch 27/50
# 3/3 [==============================] - 0s 26ms/step - loss: 0.3320 - val_loss: 0.2796
# Epoch 28/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3210 - val_loss: 0.2693
# Epoch 29/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3095 - val_loss: 0.2586
# Epoch 30/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2969 - val_loss: 0.2492
# Epoch 31/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2890 - val_loss: 0.2390
# Epoch 32/50
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2744 - val_loss: 0.2314
# Epoch 33/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.2658 - val_loss: 0.2210
# Epoch 34/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2516 - val_loss: 0.2093
# Epoch 35/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2390 - val_loss: 0.2008
# Epoch 36/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2320 - val_loss: 0.1915
# Epoch 37/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2211 - val_loss: 0.1821
# Epoch 38/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2098 - val_loss: 0.1744
# Epoch 39/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2024 - val_loss: 0.1663
# Epoch 40/50
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1935 - val_loss: 0.1567
# Epoch 41/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1850 - val_loss: 0.1493
# Epoch 42/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1772 - val_loss: 0.1417
# Epoch 43/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1671 - val_loss: 0.1376
# Epoch 44/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1622 - val_loss: 0.1302
# Epoch 45/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1518 - val_loss: 0.1247
# Epoch 46/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1513 - val_loss: 0.1214
# Epoch 47/50
# 3/3 [==============================] - 0s 27ms/step - loss: 0.1402 - val_loss: 0.1140
# Epoch 48/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1338 - val_loss: 0.1118
# Epoch 49/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1307 - val_loss: 0.1050
# Epoch 50/50
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1227 - val_loss: 0.1004

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# * 예측 및 검증
#     * 예측 결과는 softmax로 변환된 값 입니다.

# %%
pred = model.predict(x_val)
pred_1 = pred.argmax(axis=1)
# Out:
# 2/2 [==============================] - 0s 15ms/step

# %%
print(confusion_matrix(y_val, pred_1))
print(classification_report(y_val, pred_1))
# Out:
# [[13  0  0]
#  [ 0 18  0]
#  [ 0  4 10]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.82      1.00      0.90        18
#            2       1.00      0.71      0.83        14
#
#     accuracy                           0.91        45
#    macro avg       0.94      0.90      0.91        45
# weighted avg       0.93      0.91      0.91        45

# %% [markdown]
# ## 5.참조 : y를 one-hot encoding 하여 모델링
#
# * y 가변수화 : to_categorical
# * 컴파일에서 loss = 'categorical_crossentropy'

# %%
from keras.utils import to_categorical

# %% [markdown]
# ### (1) y에 대한 가변수화

# %%
y

# %%
y_c = to_categorical(y.values, 3)

# %%
y_c[:5]

# %% [markdown]
# ### (2) 데이터 분할2 : train : val

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y_c, test_size = .3, random_state = 2022)

# %%
y_train.shape

# %% [markdown]
# ### (3) Scaling

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (4) 모델 설계

# %%
nfeatures = x_train.shape[1] #num of columns
nfeatures

# %%
# 메모리 정리
clear_session()

# Sequential
model = Sequential([Dense(3, input_shape = (nfeatures,), activation = 'softmax')])

# 모델요약
model.summary()

# %% [markdown]
# ### (5) compile + 학습
#
# * lr과 learning_rate은 같은 의미 입니다. 그러나 향후 버전에서는 lr이 제외될 예정이라고 합니다.
# * y를 one-hot encoding 했다면, loss fuction은 **categorical_crossentropy** 입니다.

# %%
model.compile(optimizer=Adam(learning_rate=0.1), loss='categorical_crossentropy')

history = model.fit(x_train, y_train, epochs = 100,
                    validation_split=0.2).history

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# ### (6) 예측 및 평가
# * 예측 결과는 softmax로 변환된 값 입니다.

# %%
pred = model.predict(x_val)
pred[:5]

# %% [markdown]
# * 행 별로 제일 큰 값을 찾아서 그에 맞게 숫자(0,1,2)로 변환 합시다.

# %%
# 5개 행만 살펴보면
np.argmax(pred[:5], axis = 1)

# %%
y_val

# %%
# 전체에 적용해서 변환합시다.
pred_1 = pred.argmax(axis=1)
pred_1

# %% [markdown]
# * 실제값 y_val도 원래 대로 돌려 놓습니다.

# %%
y_val[:5]

# %%
y_val_1 = y_val.argmax(axis=1)
y_val_1

# %%
print(confusion_matrix(y_val_1, pred_1))
print(classification_report(y_val_1, pred_1))
