# %% [markdown]
# # Classification : 2 Class

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense
from keras.backend import clear_session
from keras.optimizers import Adam

# %% [markdown]
# * 학습곡선 함수

# %%
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### (2) 데이터로딩

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.3.csv"
data = pd.read_csv(path)
data.drop(['Age_scale1', 'AgeGroup', 'SibSp','Parch' ], axis = 1, inplace = True)
data.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare Embarked  Family
# 0         0       3    male  22.0   7.2500        S       2
# 1         1       1  female  38.0  71.2833        C       2
# 2         1       3  female  26.0   7.9250        S       1
# 3         1       1  female  35.0  53.1000        S       2
# 4         0       3    male  35.0   8.0500        S       1

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# Sex, Age, Fare 만 이용하여 Survived 를 예측하는 모델을 만들어 봅시다.

# %% [markdown]
# ### (1) 데이터 준비

# %%
target = 'Survived'
features = ['Sex', 'Age', 'Fare']
x = data.loc[:, features]
y = data.loc[:, target]

# %% [markdown]
# ### (2) 가변수화

# %%
x = pd.get_dummies(x, columns = ['Sex'], drop_first = True)
x.head()
# Out:
#     Age     Fare  Sex_male
# 0  22.0   7.2500         1
# 1  38.0  71.2833         0
# 2  26.0   7.9250         0
# 3  35.0  53.1000         0
# 4  35.0   8.0500         1

# %% [markdown]
# ### (3) 데이터분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.3, random_state = 20)

# %% [markdown]
# ### (4) Scaling

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ## 3.딥러닝1: 3개 feature

# %% [markdown]
# ### (1) 모델설계

# %%
nfeatures = x_train.shape[1]
nfeatures
# Out:
# 3

# %%
# 메모리 정리
clear_session()

# Sequential 모델 만들기
model = Sequential( Dense( 1 , input_shape = (nfeatures ,), activation= 'sigmoid') )

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 4
#
# =================================================================
# Total params: 4 (16.00 Byte)
# Trainable params: 4 (16.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### (2) compile + 학습

# %%
model.compile(optimizer = Adam(learning_rate=0.01), loss = 'binary_crossentropy')

history = model.fit(x_train, y_train, epochs = 50, validation_split=0.2).history
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 15ms/step - loss: 0.6497 - val_loss: 0.6302
# Epoch 2/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.6274 - val_loss: 0.6112
# Epoch 3/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5020 - val_loss: 0.4910
# Epoch 32/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5014 - val_loss: 0.4909
# Epoch 33/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5008 - val_loss: 0.4907
# Epoch 34/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5004 - val_loss: 0.4894
# Epoch 35/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5001 - val_loss: 0.4900
# Epoch 36/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4993 - val_loss: 0.4894
# Epoch 37/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4989 - val_loss: 0.4891
# Epoch 38/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4984 - val_loss: 0.4886
# Epoch 39/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4981 - val_loss: 0.4890
# Epoch 40/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4976 - val_loss: 0.4886
# Epoch 41/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4972 - val_loss: 0.4885
# Epoch 42/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4969 - val_loss: 0.4882
# Epoch 43/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4967 - val_loss: 0.4879
# Epoch 44/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4966 - val_loss: 0.4882
# Epoch 45/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4962 - val_loss: 0.4874
# Epoch 46/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4959 - val_loss: 0.4871
# Epoch 47/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4954 - val_loss: 0.4872
# Epoch 48/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4956 - val_loss: 0.4879
# Epoch 49/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4951 - val_loss: 0.4880
# Epoch 50/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4949 - val_loss: 0.4874

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# ### (3) 예측 및 검증

# %%
pred = model.predict(x_val)

# activation이 sigmoid --> 0 ~ 1 사이의 확률값.
# 그러므로 cut-off value(보통 0.5)를 기준으로 잘라서 0과 1로 만들어 준다.
pred = np.where(pred >= .5, 1, 0)
# Out:
# 9/9 [==============================] - 0s 3ms/step

# %%
print(classification_report(y_val, pred))
pred[:5]
# activation이 sigmoid --> 0 ~ 1 사이의 확률값
# 그러므로 cut-off value(보통 0.5)를 기준으로 잘라서 0과 1로 만들어 준다.
# pred = np.where(pred >= .5, 1, 0)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82       170
#            1       0.70      0.68      0.69        98
#
#     accuracy                           0.78       268
#    macro avg       0.76      0.76      0.76       268
# weighted avg       0.78      0.78      0.78       268
# array([[1],
#        [0],
#        [0],
#        [0],
#        [1]])

# %% [markdown]
# ## 4.딥러닝2 : 전체 feature
# * 이제 전체 데이터를 가지고 모델링을 시도해 보겠습니다.

# %% [markdown]
# ### (1) 데이터 전처리

# %% [markdown]
# * 데이터 준비

# %%
target = 'Survived'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# * 가변수화

# %%
cat_cols = ['Pclass','Sex', 'Embarked']
x = pd.get_dummies(x, columns = cat_cols, drop_first = True)

# %% [markdown]
# * 데이터분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.3, random_state = 20)

# %% [markdown]
# * 스케일링

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### (2) 모델링

# %% [markdown]
# * 모델 설계

# %%
nfeatures = x_train.shape[1]
nfeatures
# Out:
# 8

# %%
# 메모리 정리
clear_session()

# Sequential 모델 만들기
model = Sequential([Dense(1 , input_shape = (nfeatures ,), activation= 'sigmoid')])

# 모델요약
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 9
#
# =================================================================
# Total params: 9 (36.00 Byte)
# Trainable params: 9 (36.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# * compile + 학습

# %%
model.compile(optimizer = Adam(learning_rate=0.01), loss = 'binary_crossentropy')

history = model.fit(x_train, y_train, epochs = 100, validation_split=0.2).history
# Out:
# Epoch 1/100
# 16/16 [==============================] - 1s 13ms/step - loss: 0.8949 - val_loss: 0.8558
# Epoch 2/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.7969 - val_loss: 0.7687
# Epoch 3/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.7422 - val_loss: 0.7237
# Epoch 4/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.7103 - val_loss: 0.6921
# Epoch 5/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6850 - val_loss: 0.6643
# Epoch 6/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.6611 - val_loss: 0.6428
# Epoch 7/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6407 - val_loss: 0.6218
# Epoch 8/100
# 16/16 [==============================] - 0s 6ms/step - loss: 0.6229 - val_loss: 0.6042
# Epoch 9/100
# 16/16 [==============================] - 0s 6ms/step - loss: 0.6073 - val_loss: 0.5883
# Epoch 10/100
# 16/16 [==============================] - 0s 5ms/step - loss: 0.5933 - val_loss: 0.5739
# Epoch 11/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5811 - val_loss: 0.5616
# Epoch 12/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5695 - val_loss: 0.5512
# Epoch 13/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5602 - val_loss: 0.5410
# Epoch 14/100
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5511 - val_loss: 0.5328
# Epoch 15/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5433 - val_loss: 0.5250
# Epoch 16/100
# 16/16 [==============================] - 0s 6ms/step - loss: 0.4418 - val_loss: 0.4414

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(history)

# %% [markdown]
# * 예측 및 검증

# %%
pred = model.predict(x_val)

# activation이 sigmoid --> 0 ~ 1 사이의 확률값.
# 그러므로 cut-off value(보통 0.5)를 기준으로 잘라서 0과 1로 만들어 준다.
pred = np.where(pred >= .5, 1, 0)

print(classification_report(y_val, pred))
pred[:5]
# activation이 sigmoid --> 0 ~ 1 사이의 확률값
# 그러므로 cut-off value(보통 0.5)를 기준으로 잘라서 0과 1로 만들어 준다.
# pred = np.where(pred >= .5, 1, 0)
# Out:
# 9/9 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       170
#            1       0.70      0.67      0.69        98
#
#     accuracy                           0.78       268
#    macro avg       0.76      0.75      0.76       268
# weighted avg       0.77      0.78      0.78       268
# array([[1],
#        [0],
#        [0],
#        [0],
#        [1]])

# %% [markdown]
# ----

# %% [markdown]
# ## 5.딥러닝3 : hidden layer
# * 이제 레이어를 추가해 보겠습니다.

# %% [markdown]
# ### (1) 모델 설계

# %%
n = x_train.shape[1]
n
# Out:
# 8

# %%
# 메모리 정리
clear_session()

# Sequential 모델
model3 = Sequential([ Dense( 4, input_shape = (n ,), activation = 'relu'),
                      Dense( 1, activation = 'sigmoid')])

# 모델요약
model3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 36
#
#  dense_1 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 41 (164.00 Byte)
# Trainable params: 41 (164.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### (2) compile + 학습

# %%
model3.compile( optimizer=Adam(learning_rate= 0.01), loss ='binary_crossentropy')
hist = model3.fit(x_train, y_train, epochs = 50, validation_split=.2 ).history
# Out:
# Epoch 1/50
# 16/16 [==============================] - 3s 42ms/step - loss: 0.7320 - val_loss: 0.6789
# Epoch 2/50
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6664 - val_loss: 0.6393
# Epoch 3/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.6370 - val_loss: 0.6107
# Epoch 4/50
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6090 - val_loss: 0.5811
# Epoch 5/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.5819 - val_loss: 0.5529
# Epoch 6/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.5585 - val_loss: 0.5331
# Epoch 7/50
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5385 - val_loss: 0.5160
# Epoch 8/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.5208 - val_loss: 0.5023
# Epoch 9/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.5098 - val_loss: 0.4885
# Epoch 10/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4962 - val_loss: 0.4768
# Epoch 11/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.4875 - val_loss: 0.4689
# Epoch 12/50
# 16/16 [==============================] - 0s 9ms/step - loss: 0.4781 - val_loss: 0.4634
# Epoch 41/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4343 - val_loss: 0.4468
# Epoch 42/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4315 - val_loss: 0.4456
# Epoch 43/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4329 - val_loss: 0.4472
# Epoch 44/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4328 - val_loss: 0.4439
# Epoch 45/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4314 - val_loss: 0.4465
# Epoch 46/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4319 - val_loss: 0.4462
# Epoch 47/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4319 - val_loss: 0.4494
# Epoch 48/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4316 - val_loss: 0.4517
# Epoch 49/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4329 - val_loss: 0.4513
# Epoch 50/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4401 - val_loss: 0.4469

# %% [markdown]
# * 학습결과 그래프

# %%
dl_history_plot(hist)

# %% [markdown]
# * 예측 및 검증

# %%
pred3 = model3.predict(x_val)
pred3 = np.where(pred3 >= 0.5, 1, 0)
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %%
print(classification_report(y_val, pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82       170
#            1       0.69      0.69      0.69        98
#
#     accuracy                           0.77       268
#    macro avg       0.75      0.76      0.76       268
# weighted avg       0.77      0.77      0.77       268

# %% [markdown]
# ### (3) 실습1

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape | 옵션 |
# | ---- | ---- | ---- |
# | dense (Dense) | (None, 16)  | node, input_shape, activation = 'relu' |
# | dense_1 (Dense) | (None, 1) | node, activation = 'sigmoid' |

# %%
clear_session()

model5 = Sequential([Dense(16, input_shape = (nfeatures,), activation = 'relu'),
                     Dense(1, activation = 'sigmoid')])

model5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                144
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 161 (644.00 Byte)
# Trainable params: 161 (644.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model5.compile(optimizer=Adam(learning_rate=0.01), loss ='binary_crossentropy')

# %%
hist = model5.fit(x_train, y_train,epochs = 50, validation_split=.2 ).history
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 14ms/step - loss: 0.6672 - val_loss: 0.5767
# Epoch 2/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.5526 - val_loss: 0.5036
# Epoch 3/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4998 - val_loss: 0.4648
# Epoch 4/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4697 - val_loss: 0.4456
# Epoch 5/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4496 - val_loss: 0.4388
# Epoch 6/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4428 - val_loss: 0.4335
# Epoch 35/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3948 - val_loss: 0.4006
# Epoch 36/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3904 - val_loss: 0.4169
# Epoch 37/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3943 - val_loss: 0.3937
# Epoch 38/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3884 - val_loss: 0.4060
# Epoch 39/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3902 - val_loss: 0.3969
# Epoch 40/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3897 - val_loss: 0.3956
# Epoch 41/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3862 - val_loss: 0.4015
# Epoch 42/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3858 - val_loss: 0.3951
# Epoch 43/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3925 - val_loss: 0.4119
# Epoch 44/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3921 - val_loss: 0.3983
# Epoch 45/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3883 - val_loss: 0.4047
# Epoch 46/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3858 - val_loss: 0.3920
# Epoch 47/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3901 - val_loss: 0.4099
# Epoch 48/50
# 16/16 [==============================] - 0s 6ms/step - loss: 0.3906 - val_loss: 0.3993
# Epoch 49/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3836 - val_loss: 0.3966
# Epoch 50/50
# 16/16 [==============================] - 0s 7ms/step - loss: 0.3833 - val_loss: 0.3965

# %%
dl_history_plot(hist)

# %%
pred3 = model5.predict(x_val)
pred3 = np.where(pred3 >= 0.5, 1, 0)
# Out:
# 9/9 [==============================] - 0s 7ms/step

# %%
print(classification_report(y_val, pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       170
#            1       0.78      0.64      0.70        98
#
#     accuracy                           0.80       268
#    macro avg       0.80      0.77      0.78       268
# weighted avg       0.80      0.80      0.80       268

# %% [markdown]
# ### (4) 실습2

# %% [markdown]
# * 다음의 summary를 보고 모델을 설계하시오.
#
# | Layer (type) | Output Shape |  옵션 |
# | ---- | ---- | ---- |
# | dense (Dense) | (None, 16) |  node, input_shape, activation = 'relu' |
# | dense_1 (Dense) | (None, 8) |  node, activation = 'relu'  |
# | dense_2 (Dense) | (None, 1) |  node, activation = 'sigmoid'  |

# %%
clear_session()

model6 = Sequential([Dense(16, input_shape = (nfeatures,), activation = 'relu'),
                     Dense(8, activation = 'relu'),
                     Dense(1, activation = 'sigmoid')])

model6.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                144
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 289 (1.13 KB)
# Trainable params: 289 (1.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
