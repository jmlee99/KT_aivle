# %% [markdown]
# # **종합실습2 이변량분석(y-범주) : 직원 이직 분석**

# %% [markdown]
# ![](https://www.talentalign.com/wp-content/uploads/2019/09/main-qimg-2434943004743f79c0abf540cb4f6e2c-cropped.jpg)

# %% [markdown]
# * 직원 이직 분석
#     * 회사에서 최근 1~2년 사이 이직률이 상승하였습니다.
#     * 여러분은, 직원들이 이직하는데 중요한 요인이 무엇인지 데이터를 기반으로 한 분석을 의뢰 받았습니다.

# %% [markdown]
# ## **1.환경준비**

# %% [markdown]
# * 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.mosaicplot import mosaic      #mosaic plot!

import scipy.stats as spst

# %% [markdown]
# * 데이터 불러오기 : 다음의 예제 데이터를 사용합니다.

# %%
# 직원 이직 데이터
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/Attrition_simple3.csv'
data = pd.read_csv(path)
data.head(5)
# Out:
#    Attrition  Age  DistanceFromHome  EmployeeNumber  Gender  JobSatisfaction  \
# 0          0   27                 2            1898  Female                3
# 1          0   27                 9            1965    Male                4
# 2          0   44                 2            1703  Female                4
# 3          0   42                 2            1231    Male                1
# 4          0   32                 1            2016  Female                4
#
#   MaritalStatus  MonthlyIncome OverTime  PercentSalaryHike  TotalWorkingYears
# 0        Single           6500       No                 14                  9
# 1        Single           4105       No                 14                  7
# 2       Married           7879      Yes                 19                  9
# 3       Married           6272       No                 16                 10
# 4       Married          10422       No                 19                 14

# %% [markdown]
# > * 변수설명
#     * **Attrition**	:	이직여부, Yes , No (**Target**)
#     * **Age**	:	나이
#     * **DistanceFromHome**	:	집-직장 거리(마일)
#     * **EmployeeNumber**	:	사번
#     * **Gender**	:	성별(Male, Female)
#     * **JobSatisfaction**	:	직무 만족도, 다음시트 참조
#     * **MaritalStatus**	:	결혼상태(Married, Single, Divorced)
#     * **MonthlyIncome**	:	월급(달러)
#     * **OverTime**	:	야근여부
#     * **PercentSalaryHike**	:	전년대비 급여인상율(%)
#     * **TotalWorkingYears**	:	총 근무 연수

# %%
# Attrition
target = 'Attrition'
data[target].value_counts()
# 0 - 이직안한 사람
# 1 - 이직한 사람
# Out:
# Attrition
# 0    405
# 1    195
# Name: count, dtype: int64

# %%
# Attrition
target = 'Attrition'
data[target].value_counts(normalize = True)
# 0 - 이직안한 사람 전체  총 평균은 0.625이다.
# 1 - 이직한 사람의 전체 평균 0.325다.
# Out:
# Attrition
# 0    0.675
# 1    0.325
# Name: proportion, dtype: float64

# %%
sns.countplot(x = target, data = data)
plt.grid()

# %%
# Overtime

# Attrition
var = 'Attrition'
data[var].value_counts()
# Out:
# Attrition
# 0    405
# 1    195
# Name: count, dtype: int64

# %%
var = 'Attrition'
data[var].value_counts(normalize = True)
# Out:
# Attrition
# 0    0.675
# 1    0.325
# Name: proportion, dtype: float64

# %%
sns.countplot(x = var, data = data)
plt.grid()
plt.show()

# %%
var = 'PercentSalaryHike'
data[[var]].describe().T
# Out:
#                    count       mean       std   min   25%   50%   75%   max
# PercentSalaryHike  600.0  15.288333  3.667098  11.0  12.0  14.0  18.0  25.0

# %%
sns.histplot(x = var, data = data, bins = 10)
# Out:
# <Axes: xlabel='PercentSalaryHike', ylabel='Count'>

# %% [markdown]
# ## **2.범주-->범주**

# %%
target = 'Attrition'

# %% [markdown]
# ### **(1) Gender --> Attrition**

# %%
feature = 'Gender'

# %% [markdown]
# * 교차표

# %%
# 두 범주별 빈도수를 교차표로 만들어 봅시다.
pd.crosstab(data[target], data[feature])
# Out:
# Gender     Female  Male
# Attrition
# 0             157   248
# 1              66   129

# %%
pd.crosstab(data[target], data[feature], normalize = 'columns')
# Out:
# Gender       Female      Male
# Attrition
# 0          0.704036  0.657825
# 1          0.295964  0.342175

# %% [markdown]
# * 시각화

# %%
mosaic(data, [ feature,target])
plt.axhline(1- data[target].mean(), color = 'r')
plt.show()

# %% [markdown]
# * 수치화 : 카이제곱검정

# %%
# 먼저 집계
table = pd.crosstab(data[target], data[feature])
print('교차표\n', table)
print('-' * 100)

# 카이제곱검정
result = spst.chi2_contingency(table)
print('카이제곱통계량', result[0])
print('p-value', result[1])
print('자유도', result[2])
print('기대빈도\n',result[3])

# 시각적으로 보면 차이가 있는 것 같지만, 수치적으로 보면 차이가 없다.
# 그럼 무조건 차이가 없다고 말할 수 있는가? ==> 그것은 이 관련 비즈니스의 사람과 토론을 통해 결정해야 하는 부분이다.
# Out:
# 교차표
#  Gender     Female  Male
# Attrition
# 0             157   248
# 1              66   129
# ----------------------------------------------------------------------------------------------------
# 카이제곱통계량 1.1614318259891623
# p-value 0.28116879016055174
# 자유도 1
# 기대빈도
#  [[150.525 254.475]
#  [ 72.475 122.525]]

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %%
# 카이제곱검정으로는 관련이 없다고 나오나, 그래프로 볼때 약간 관련이 있다고 판단됨.

# %% [markdown]
# ### **(2) JobSatisfaction --> Attrition**

# %% [markdown]
# * 교차표

# %%
# 두 범주별 빈도수를 교차표로 만들어 봅시다.
target = 'Attrition'
feature = 'JobSatisfaction'
pd.crosstab(data[target], data[feature], normalize = 'columns')

# 이직률 평균이 0.325이고, 매우 불만족인 1이 0.41로 훨씬 높다 ==> 이 사람들은 대체 왜 이직을 하는지가 중요
# Out:
# JobSatisfaction         1         2        3         4
# Attrition
# 0                0.587302  0.681034  0.65896  0.745946
# 1                0.412698  0.318966  0.34104  0.254054

# %% [markdown]
# * 시각화

# %%
mosaic(data, [ feature,target])
plt.axhline(1- data[target].mean(), color = 'r')
plt.show()

# %% [markdown]
# * 수치화 : 카이제곱검정

# %%
table = pd.crosstab(data[target], data[feature])
print('교차표\n', table)
print('-' * 100)

# 카이제곱검정
result = spst.chi2_contingency(table)
print('카이제곱통계량', result[0])
print('p-value', result[1])
print('자유도', result[2])
print('기대빈도\n',result[3])
# Out:
# 교차표
#  JobSatisfaction   1   2    3    4
# Attrition
# 0                74  79  114  138
# 1                52  37   59   47
# ----------------------------------------------------------------------------------------------------
# 카이제곱통계량 8.884191097554549
# p-value 0.03087092125625072
# 자유도 3
# 기대빈도
#  [[ 85.05   78.3   116.775 124.875]
#  [ 40.95   37.7    56.225  60.125]]

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
# ### **(3) MaritalStatus --> Attrition**

# %% [markdown]
# * 교차표

# %%
target = 'Attrition'
feature = 'MaritalStatus'
pd.crosstab(data[target], data[feature])
# Out:
# MaritalStatus  Divorced  Married  Single
# Attrition
# 0                    89      205     111
# 1                    23       69     103

# %% [markdown]
# * 시각화

# %%
mosaic(data, [ feature,target])
plt.axhline(1- data[target].mean(), color = 'r')
plt.show()

# %% [markdown]
# * 수치화 : 카이제곱검정

# %%
table = pd.crosstab(data[target], data[feature])
print('교차표\n', table)
print('-' * 100)

# 카이제곱검정
result = spst.chi2_contingency(table)
print('카이제곱통계량', result[0])
print('p-value', result[1])
print('자유도', result[2])
print('기대빈도\n',result[3])
# Out:
# 교차표
#  MaritalStatus  Divorced  Married  Single
# Attrition
# 0                    89      205     111
# 1                    23       69     103
# ----------------------------------------------------------------------------------------------------
# 카이제곱통계량 37.829711907070525
# p-value 6.100738829354226e-09
# 자유도 2
# 기대빈도
#  [[ 75.6  184.95 144.45]
#  [ 36.4   89.05  69.55]]

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
# ### **(4) OverTime --> Attrition**

# %% [markdown]
# * 교차표

# %%
target = 'Attrition'
feature = 'OverTime'
pd.crosstab(data[target], data[feature])
# Out:
# OverTime    No  Yes
# Attrition
# 0          315   90
# 1           90  105

# %% [markdown]
# * 시각화

# %%
mosaic(data, [ feature,target])
plt.axhline(1- data[target].mean(), color = 'r')
plt.show()

# %% [markdown]
# * 수치화 : 카이제곱검정

# %%
table = pd.crosstab(data[target], data[feature])
print('교차표\n', table)
print('-' * 100)

# 카이제곱검정
result = spst.chi2_contingency(table)
print('카이제곱통계량', result[0])
print('p-value', result[1])
print('자유도', result[2])
print('기대빈도\n',result[3])
# Out:
# 교차표
#  OverTime    No  Yes
# Attrition
# 0          315   90
# 1           90  105
# ----------------------------------------------------------------------------------------------------
# 카이제곱통계량 58.57149427899665
# p-value 1.9603625783060702e-14
# 자유도 1
# 기대빈도
#  [[273.375 131.625]
#  [131.625  63.375]]

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
# ## **3.숫자-->범주**

# %% [markdown]
# ### **(1) Age --> Attrition**

# %%
feature = 'Age'

# %%
sns.kdeplot(x= feature, data = data, hue = target,
            common_norm = False)
plt.show()

# %%
sns.kdeplot(x= feature, data = data, hue = target
            , multiple = 'fill')
plt.axhline(data[target].mean(), color = 'r')
plt.show()

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %%
sns.histplot(x= feature, data = data, hue = target
            , multiple = 'fill')
plt.axhline(data[target].mean(), color = 'r')
plt.show()

# %% [markdown]
# ### **(2) DistanceFromHome --> Attrition**

# %%
def draw_graph(feature, target):
    fig, axes = plt.subplots(1,3, figsize = (30, 10))
    sns.kdeplot(x= feature, data = data, hue = target,
                common_norm = False, ax = axes[0])
    sns.histplot(x= feature, data = data, hue = target
                , multiple = 'fill', ax = axes[1])
    axes[1].axhline(data[target].mean(), color = 'r')
    sns.kdeplot(x= feature, data = data, hue = target
                , multiple = 'fill', ax = axes[2])
    axes[2].axhline(data[target].mean(), color = 'r')

# %%
draw_graph('DistanceFromHome', 'Attrition')

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
# ### **(3) MonthlyIncome --> Attrition**

# %%
draw_graph('MonthlyIncome', 'Attrition')

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
# ### **(4) PercentSalaryHike --> Attrition**

# %%
draw_graph('PercentSalaryHike', 'Attrition')

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
# ### **(5) TotalWorkingYears --> Attrition**

# %%
draw_graph('TotalWorkingYears', 'Attrition')

# %% [markdown]
# * 파악된 내용을 기술해 봅시다.

# %% [markdown]
# ## **4.관계 정리하기**

# %% [markdown]
# ① 강한관계

# %% [markdown]
# ② 중간관계

# %% [markdown]
# ③ 관계없음(약한 관계)
