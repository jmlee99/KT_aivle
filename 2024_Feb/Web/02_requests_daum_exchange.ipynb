# %% [markdown]
# ### Daum Exchange
# - `https://finance.daum.net`

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import requests

# %%
# 1. URL
url = 'https://finance.daum.net/api/exchanges/summaries'

# header 설정
headers = {
    'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36'
    , 'Referer' : 'https://finance.daum.net/exchanges',
}

# 2. request > response : json(str)
response = requests.get(url, headers = headers)
response

# 3. json(str) > list,dict : DataFrame
data = response.json()['data']
df = pd.DataFrame(data)[['symbolCode', 'currencyCode', 'basePrice']]
df
# Out:
#     symbolCode currencyCode  basePrice
# 0   FRX.KRWUSD          USD    1331.50
# 1   FRX.KRWJPY          JPY     898.30
# 2   FRX.KRWCNY          CNY     184.63
# 3   FRX.KRWEUR          EUR    1451.07
# 4   FRX.KRWGBP          GBP    1695.67
# 5   FRX.KRWCHF          CHF    1510.32
# 6   FRX.KRWCAD          CAD     985.35
# 7   FRX.KRWNZD          NZD     818.41
# 8   FRX.KRWHKD          HKD     170.27
# 9   FRX.KRWBRL          BRL     269.26
# 10  FRX.KRWMXN          MXN      78.88
# 11  FRX.KRWAED          AED     362.53
# 12  FRX.KRWKWD          KWD    4331.63
# 13  FRX.KRWBHD          BHD    3532.11
# 14  FRX.KRWINR          INR      16.08
# 15  FRX.KRWSAR          SAR     355.01
# 16  FRX.KRWNOK          NOK     126.99
# 17  FRX.KRWDKK          DKK     194.67
# 18  FRX.KRWMYR          MYR     283.36
# 19  FRX.KRWBDT          BDT      12.13
# 20  FRX.KRWPKR          PKR       4.77
# 21  FRX.KRWIDR          IDR       8.53
# 22  FRX.KRWTWD          TWD      42.23
# 23  FRX.KRWPHP          PHP      23.84
# 24  FRX.KRWSEK          SEK     129.35
# 25  FRX.KRWAUD          AUD     876.26
# 26  FRX.KRWSGD          SGD     995.89
# 27  FRX.KRWTHB          THB      37.40
# 28  FRX.KRWEGP          EGP      26.82
# 29  FRX.KRWBND          BND     995.89
# 30  FRX.KRWILS          ILS     371.61
# 31  FRX.KRWJOD          JOD    1877.86
# 32  FRX.KRWVND          VND       5.39
# 33  FRX.KRWRUB          RUB      14.64
# 34  FRX.KRWHUF          HUF       3.68
# 35  FRX.KRWPLN          PLN     337.21
# 36  FRX.KRWZAR          ZAR      70.60
# 37  FRX.KRWMNT          MNT       0.39
# 38  FRX.KRWCZK          CZK      57.20
# 39  FRX.KRWKZT          KZT       2.98
# 40  FRX.KRWQAR          QAR     365.14
# 41  FRX.KRWTRY          TRY      41.81
